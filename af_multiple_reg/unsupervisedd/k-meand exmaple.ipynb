# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("student_clustering (1).csv")

# %%
data
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
plt.scatter(data["cgpa"], data["iq"], label = "DataSet")
plt.xlabel("cgpa")
plt.ylabel("IQ")
plt.legend()

# %%
# Elbow Methods

# %%
from sklearn.cluster import KMeans

# %%
check_wcss = KMeans(n_clusters = 1)

check_wcss.fit_predict(data)

check_wcss.inertia_
# Out:
# 29957.898288000004

# %%
check_wcss = KMeans(n_clusters = 2)

check_wcss.fit_predict(data)

check_wcss.inertia_
# Out:
# 4184.141270000001

# %%
check_wcss = KMeans(n_clusters = 3)

check_wcss.fit_predict(data)

check_wcss.inertia_
# Out:
# 2364.005583420084

# %%
check_wcss = KMeans(n_clusters = 4)

check_wcss.fit_predict(data)

check_wcss.inertia_
# Out:
# 681.9696600000003

# %%
check_wcss = KMeans(n_clusters = 5)

check_wcss.fit_predict(data)

check_wcss.inertia_
# Out:
# 514.1616803171116

# %%
check_wcss = KMeans(n_clusters = 6)

check_wcss.fit_predict(data)

check_wcss.inertia_
# Out:
# 515.3871254832743

# %%
wcss = []

# %%
for i in range(1, 10):
    check_wcss = KMeans(n_clusters = i)
    check_wcss.fit_predict(data)
    wcss.append(check_wcss.inertia_)

# %%
wcss
# Out:
# [29957.898288000004,
#  4184.141270000001,
#  2503.397581000001,
#  681.9696600000003,
#  514.1616803171116,
#  446.79961657655315,
#  322.98151764399097,
#  257.48715962321666,
#  204.4170171706271]

# %%
plt.plot(range(1, 10), wcss, label = "Elbow Curve", marker = ".", ms = 15, mec = "green", mfc = "yellow")
plt.xlabel("number of cluster")
plt.ylabel("WCSS / Inertia..")
plt.legend()

for i in range(1, 10):
    plt.annotate(xy = (i, wcss[i-1]), text = f"({i}, {str(wcss[i-1])[:5]})")

# %%
algo = KMeans(n_clusters = 4)

# %%
algo.fit(data)
# Out:
# KMeans(n_clusters=4)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
new_data = data.values

# %%
new_data
# Out:
# array([[  5.13,  88.  ],
#        [  5.9 , 113.  ],
#        [  8.36,  93.  ],
#        [  8.27,  97.  ],
#        [  5.45, 110.  ],
#        [  5.88, 109.  ],
#        [  8.41,  98.  ],
#        [  8.8 , 115.  ],
#        [  5.79, 110.  ],
#        [  8.09,  94.  ],
#        [  4.6 ,  86.  ],
#        [  6.1 , 110.  ],
#        [  8.16,  97.  ],
#        [  5.  ,  88.  ],
#        [  5.71, 108.  ],
#        [  8.31,  95.  ],
#        [  5.5 , 111.  ],
#        [  7.87,  91.  ],
#        [  6.05, 111.  ],
#        [  5.84, 113.  ],
#        [  7.47,  98.  ],
#        [  4.86,  86.  ],
#        [  7.78,  92.  ],
#        [  4.78,  87.  ],
#        [  4.96,  88.  ],
#        [  7.93,  98.  ],
#        [  4.86,  87.  ],
#        [  9.18, 119.  ],
#        [  8.04,  94.  ],
#        [  5.43, 106.  ],
#        [  8.86, 117.  ],
#        [  6.01, 112.  ],
#        [  8.83, 118.  ],
#        [  5.32, 106.  ],
#        [  7.77,  96.  ],
#        [  8.  ,  96.  ],
#        [  8.56, 118.  ],
# ...

# %%
predictions = algo.fit_predict(new_data)

# %%
predictions
# Out:
# array([1, 0, 3, 3, 0, 0, 3, 2, 0, 3, 1, 0, 3, 1, 0, 3, 0, 3, 0, 0, 3, 1,
#        3, 1, 1, 3, 1, 2, 3, 0, 2, 0, 2, 0, 3, 3, 2, 0, 1, 0, 1, 3, 3, 1,
#        2, 2, 3, 0, 2, 0, 1, 1, 2, 3, 2, 0, 0, 2, 0, 2, 0, 3, 3, 2, 1, 2,
#        3, 1, 0, 3, 0, 2, 3, 1, 0, 2, 0, 2, 1, 3, 3, 2, 0, 1, 2, 1, 2, 0,
#        2, 0, 2, 2, 3, 1, 3, 3, 2, 3, 1, 2, 0, 1, 1, 2, 1, 1, 3, 1, 2, 2,
#        3, 2, 0, 0, 3, 2, 3, 0, 2, 1, 1, 0, 3, 2, 3, 1, 3, 0, 1, 3, 3, 0,
#        1, 1, 0, 2, 0, 1, 3, 3, 3, 1, 0, 1, 1, 2, 1, 2, 0, 1, 2, 1, 2, 2,
#        1, 3, 0, 2, 0, 3, 1, 2, 0, 3, 2, 1, 0, 1, 1, 2, 2, 0, 2, 1, 1, 3,
#        2, 0, 1, 2, 2, 0, 0, 0, 3, 1, 3, 3, 2, 0, 3, 3, 1, 1, 3, 1, 2, 0,
#        0, 2])

# %%
data
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
predictions == 2
# Out:
# array([False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False,  True, False,  True, False, False, False,
#         True, False, False, False, False, False, False, False,  True,
#         True, False, False,  True, False, False, False,  True, False,
#         True, False, False,  True, False,  True, False, False, False,
#         True, False,  True, False, False, False, False, False,  True,
#        False, False, False,  True, False,  True, False, False, False,
#         True, False, False,  True, False,  True, False,  True, False,
#         True,  True, False, False, False, False,  True, False, False,
#         True, False, False, False,  True, False, False, False, False,
#         True,  True, False,  True, False, False, False,  True, False,
# ...

# %%
data[predictions == 1]
# Out:
#      cgpa  iq
# 0    5.13  88
# 10   4.60  86
# 13   5.00  88
# 21   4.86  86
# 23   4.78  87
# 24   4.96  88
# 26   4.86  87
# 38   5.44  84
# 40   5.34  85
# 43   5.31  86
# 50   5.14  83
# 51   4.95  86
# 64   5.21  87
# 67   4.91  85
# 73   5.28  83
# 78   5.15  88
# 83   4.90  85
# 85   4.89  88
# 93   5.05  86
# 98   4.98  91
# 101  5.01  86
# 102  4.95  88
# 104  4.96  89
# 105  4.85  86
# 107  4.76  90
# 119  4.98  87
# 120  4.78  87
# 125  5.20  85
# 128  5.05  87
# 132  5.01  83
# 133  4.77  86
# 137  4.68  87
# 141  4.81  85
# 143  5.03  87
# 144  4.98  87
# 146  5.32  88
# 149  4.86  88
# 151  4.89  85
# 154  4.88  86
# 160  5.01  86
# 165  4.67  86
# 167  5.15  85
# 168  4.97  88
# 173  4.87  88
# 174  5.20  89
# 178  4.99  88
# 185  4.79  88
# 192  4.76  89
# 193  4.78  85
# 195  4.68  89

# %%
data[predictions == 2]["iq"]
# Out:
# 2       93
# 3       97
# 6       98
# 9       94
# 12      97
# 15      95
# 17      91
# 20      98
# 22      92
# 25      98
# 28      94
# 34      96
# 35      96
# 41      96
# 42      93
# 46      94
# 53      96
# 61      96
# 62      95
# 66      93
# 69      95
# 72      94
# 79      92
# 80      91
# 92      92
# 94      95
# 95      94
# 97      95
# 106     92
# 110     94
# 114     91
# 116     95
# 122     93
# 124     97
# 126     98
# 129     96
# 130     93
# 138    100
# 139     96
# 140     94
# 155     95
# 159     93
# 163     92
# 175     98
# 184     96
# 186     93
# 187     91
# 190     93
# 191     94
# 194     96
# Name: iq, dtype: int64

# %%
plt.scatter(data[predictions == 0]["cgpa"], data[predictions == 0]["iq"], label = "0th cluster")
plt.scatter(data[predictions == 1]["cgpa"], data[predictions == 1]["iq"], label = "1th cluster")
plt.scatter(data[predictions == 2]["cgpa"], data[predictions == 2]["iq"], label = "2th cluster")
plt.scatter(data[predictions == 3]["cgpa"], data[predictions == 3]["iq"], label = "2th cluster")


plt.xlabel("cgpa")
plt.ylabel("IQ")
plt.legend()
